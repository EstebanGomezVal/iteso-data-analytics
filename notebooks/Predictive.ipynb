# %%
from sklearn.datasets import make_regression

# %%
X, y = make_regression(n_features = 1, noise = 200)

# %%
X.shape, y.shape
# Out:
# ((100, 1), (100,))

# %%
import pandas as pd

df = pd.DataFrame(X)
df.columns = ['x']
df['y'] = y
df
# Out:
#            x           y
# 0   1.842798  135.314376
# 1   1.112762 -138.246445
# 2   0.073176 -326.740840
# 3   1.130981 -126.442755
# 4   0.334540  -13.630424
# ..       ...         ...
# 95  0.270267  379.674499
# 96  0.282055  298.816801
# 97 -0.106356 -163.599668
# 98 -0.058427   88.134880
# 99 -0.135440   97.571773
#
# [100 rows x 2 columns]

# %%
df['x'].plot(kind ='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (15, 5))
plt.scatter(X, y, label = 'Random Data', c = 'red')
plt.plot(X, y, label = "Plot", c = 'green')

plt.xlabel("Features")
plt.ylabel("Target (y)")
plt.title('Scatter Example plot')
plt.legend()

# %%
import numpy as np

y_mean = np.array([y.mean()]*100)

# %%
from sklearn.linear_model import LinearRegression

model_1 = LinearRegression()
model_2 = LinearRegression()
model_3 = LinearRegression()

model_1.fit(X, y)
# Out:
# LinearRegression()

# %%
y_prend = model_1.predict(X)
y_prend
# Out:
# array([ 54.26943902,  28.08035869,  -9.2133934 ,  28.73396911,
#          0.16270491, -17.43578707, -22.28926163,  84.52497565,
#         -8.0095587 , -35.36310872,   8.70948212, -33.81285947,
#        -54.32945356, -27.70661395,  -8.50532734, -12.24403258,
#        -61.57328131, -12.16176353, -23.73552703, -28.69236896,
#        -40.76568569, -32.91677633,  33.28171291,   1.95365681,
#          7.14885895, -77.81172336, -41.13043476, -15.06386025,
#         26.39288134,  12.01235748,  31.76972594, -54.25806862,
#         20.20003937, -12.28686715, -43.88046011,  -3.98102521,
#        -13.86692469,  22.90378675, -64.08188384,  17.52401324,
#        -31.14241414, -17.07504595, -21.3071314 , -36.04878123,
#        -14.94066297, -31.86217721,   6.82030143, -25.90472299,
#          4.90209353,  -1.40609222,  10.26976592, -15.2460549 ,
#          2.32440363,   6.4345038 ,  55.79076538,  45.08125217,
#         -1.84469468, -11.64550566,  88.30449681,  -6.85430193,
# ...

# %%
X, y = make_regression(n_features = 1, noise = 30, random_state= 0)
plt.figure(figsize = (10, 4))

plt.scatter(X, y, label = 'Random Data', c = 'black')

plt.plot(X, y_mean, label = "Mean", c = 'green')

plt.plot(X, y_prend, label = "Linear Regression", c = 'blue')

plt.xlabel("Features")
plt.ylabel("Target (y)")
plt.title('Scatter Example plot')
plt.legend()

plt.savefig('../reports/figures/random1.svg')
